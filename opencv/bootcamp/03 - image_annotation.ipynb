# %%
# Import libraries
import os
import cv2 as cv
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

matplotlib.rcParams['figure.figsize'] = (9.0, 9.0)

# %matplotlib inline

# %%
def download_and_unzip(url, save_path):
    print(f"Downloading and extracting assests....", end="")

    # Downloading zip file using urllib package.
    urlretrieve(url, save_path)

    try:
        # Extracting zip file using the zipfile package.
        with ZipFile(save_path) as z:
            # Extract ZIP file contents in the same directory.
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/48hboi1m4crv1tl/opencv_bootcamp_assets_NB3.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd() + "/assets", f"opencv_bootcamp_assets_NB3.zip")

# Download if assest ZIP does not exists. 
if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)

# %%
img = cv.imread("assets/Apollo_11_Launch.jpg", cv.IMREAD_COLOR_RGB)
plt.imshow(img)
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
cv.line(img, (0,640), (1280,640), (0, 255, 255), thickness=3, lineType=cv.LINE_AA)
plt.imshow(img)

# %%
cv.circle(img, (1000,130), 50, (255,255,0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(img)

# %%
cv.rectangle(img, (600,100), (700,530), color=(255,0,255), thickness=3, lineType=cv.LINE_AA)
plt.imshow(img)

# %%
cv.putText(
    img, "Floor",
    org=(5,635),
    fontFace=cv.FONT_HERSHEY_PLAIN,
    fontScale=2.3,
    color=(0,255,255),
    thickness=2,
    lineType=cv.LINE_AA)
cv.putText(
    img, "Spaceship",
    org=(600,95),
    fontFace=cv.FONT_HERSHEY_PLAIN,
    fontScale=2.3,
    color=(255,0,255),
    thickness=2,
    lineType=cv.LINE_AA)
cv.putText(
    img, "Circle",
    org=(950,75),
    fontFace=cv.FONT_HERSHEY_PLAIN,
    fontScale=2.3,
    color=(255,255),
    thickness=2,
    lineType=cv.LINE_AA)
plt.imshow(img)

# %%
cv.putText(
    img, "negative fontScale",
    org=(1000,400),
    fontFace=cv.FONT_HERSHEY_PLAIN,
    fontScale=-2,
    color=(255,0,0),
    thickness=2,
    lineType=cv.LINE_AA)
plt.imshow(img)

# %%
cv.circle(img, (200,200), radius=30, color=(0,0,255),  thickness=-2, lineType=cv.LINE_AA)
plt.imshow(img)

# %%
cv.rectangle(img, (200,300), (300,400), color=(0,255,0), thickness=-2, lineType=cv.LINE_AA)
plt.imshow(img)
